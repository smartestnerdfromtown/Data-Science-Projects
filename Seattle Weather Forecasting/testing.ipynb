# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer="seattle_weather_prepared.csv")

# %%
df
# Out:
#       Unnamed: 0        date  precipitation  temp_max  temp_min  wind  \
# 0              0  2012-01-01            0.0      12.8       5.0   4.7
# 1              1  2012-01-02           10.9      10.6       2.8   4.5
# 2              2  2012-01-03            0.8      11.7       7.2   2.3
# 3              3  2012-01-04           20.3      12.2       5.6   4.7
# 4              4  2012-01-05            1.3       8.9       2.8   6.1
# ...          ...         ...            ...       ...       ...   ...
# 1456        1456  2015-12-27            8.6       4.4       1.7   2.9
# 1457        1457  2015-12-28            1.5       5.0       1.7   1.3
# 1458        1458  2015-12-29            0.0       7.2       0.6   2.6
# 1459        1459  2015-12-30            0.0       5.6      -1.0   3.4
# 1460        1460  2015-12-31            0.0       5.6      -2.1   3.5
#
#       weather  year     month        day
# 0     drizzle  2012   January     Sunday
# 1        rain  2012   January     Monday
# ...

# %%
df["weather"].value_counts()
# Out:
# weather
# rain       641
# sun        640
# fog        101
# drizzle     53
# snow        26
# Name: count, dtype: int64
