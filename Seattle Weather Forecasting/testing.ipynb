# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer="models_metrics.csv")

# %%
df.sort_values(by="accuracy", ascending=False)
# Out:
#                                    model_name  accuracy  precision    recall  \
# 49  tuned_random_forest_classifier_classifier  0.877133   0.894558  0.877133
# 48                   random_forest_classifier  0.873720   0.892098  0.873720
# 39                tuned_extreme_random_forest  0.873720   0.872983  0.873720
# 41                tuned_extreme_random_forest  0.873720   0.872983  0.873720
# 47                   random_forest_classifier  0.873720   0.892098  0.873720
# 52          tuned_extreme_boosting_classifier  0.866894   0.872444  0.866894
# 43                     tuned_gradien_boosting  0.863481   0.889786  0.863481
# 6                 tuned_extreme_random_forest  0.860068   0.835546  0.860068
# 50                extreme_boosting_classifier  0.856655   0.842244  0.856655
# 51                extreme_boosting_classifier  0.856655   0.842244  0.856655
# 42                          gradient_boosting  0.853242   0.841008  0.853242
# ...
